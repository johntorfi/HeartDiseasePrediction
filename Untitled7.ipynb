# %% [markdown]
# <a href="https://colab.research.google.com/github/rezatorfi/HeartDiseasePrediction/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.utils import resample
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, classification_report
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09ed4ff8-0667-47fd-8229-322c0a12559d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09ed4ff8-0667-47fd-8229-322c0a12559d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datasets_4123_6408_framingham.csv to datasets_4123_6408_framingham.csv

# %%
df = pd.read_csv('datasets_4123_6408_framingham.csv')
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df= df.drop("education",axis=1)

# %%
for value in ['cigsPerDay','BPMeds','BMI','glucose','heartRate']:
    df[value].fillna(round(df[value].mode())[0], inplace= True)

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# male               0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
categorical_val = []
continous_val = []
for column in df.columns:
    if len(df[column].unique()) <= 10:
        categorical_val.append(column)
    else:
        continous_val.append(column)

# %%
categorical_val
# Out:
# ['male',
#  'currentSmoker',
#  'BPMeds',
#  'prevalentStroke',
#  'prevalentHyp',
#  'diabetes',
#  'TenYearCHD']

# %%
continous_val
# Out:
# ['age',
#  'cigsPerDay',
#  'totChol',
#  'sysBP',
#  'diaBP',
#  'BMI',
#  'heartRate',
#  'glucose']

# %%
mpgval = df[df['TenYearCHD'] == 1]
plt.figure(figsize=(20,12))
sns.countplot(x='age',data = mpgval, hue = 'TenYearCHD', palette='husl')
plt.savefig("age&CHD.png", dpi=300)

# %%
from google.colab import files

# %%
df.hist(figsize=(20,12),bins=20)
plt.savefig("Distributions.png", dpi=300)

plt.show()

# %%
files.download("Distributions.png")

# %%
sns.pairplot(df) 
plt.savefig("PairPlot.png", dpi=300)

# %%
files.download("PairPlot.png")

# %%
plt.figure(figsize=(20,12))
sns.boxplot(data=df)

plt.savefig("boxplot.png", dpi=300)

plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.distplot(df['glucose'], kde=True, color = 'magenta')
plt.xlabel("Glucose")
plt.subplot(1,2,2)
sns.distplot(df['heartRate'], kde=True, color = 'teal')
plt.xlabel(" Heart Rate Achieved")
plt.savefig("heartRate.png", dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.distplot(df['cigsPerDay'], kde=True, color = 'magenta')
plt.xlabel("cigsPerDay")
plt.subplot(1,2,2)
sns.distplot(df['sysBP'], kde=True, color = 'teal')
plt.xlabel(" sysBP")
plt.savefig("sys.png", dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.distplot(df['age'], kde=True, color = 'magenta')
plt.xlabel("Age")
plt.subplot(1,2,2)
sns.distplot(df['BMI'], kde=True, color = 'teal')
plt.xlabel(" BMI")
plt.savefig("bmi.png", dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,10))
sns.set( font_scale=1.5)                                                  
plt.title("Age of patients")
plt.xlabel("Age")
sns.countplot(x='age',data=df)
plt.savefig("age.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.set( font_scale=1.5)                                                  
plt.title("Gender of patients")
plt.xlabel("Gender")
sns.countplot(x='male',data=df)
plt.savefig("gender.png", dpi=300)
plt.show()

# %%
#draw gender vs disease outcome


plt.figure(figsize=(30,20))
sns.set( font_scale=1.0)  
temp =df.groupby(['male','TenYearCHD']).size().unstack().plot(kind='bar',stacked=True)
plt.title('Compare gender & CHD')
plt.ylabel('Population')
plt.savefig("gender&CHD.png", dpi=300)
plt.show()

# %%
files.download("gender.png")
files.download("age.png")
files.download("gender&CHD.png")
